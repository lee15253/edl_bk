# %% [markdown]
# ## Imports

# %%
import os
import sys
import matplotlib.pyplot as plt
import ipdb

sys.path.append("..")
os.environ["ROOT_DIR"] = ".."  # this allows to use relative paths in config files
from result_inspection.toy_maze import *
from result_inspection.plot_helpers import *

# %% [markdown]
# ## Plot config

# %%
plot_kwargs = dict(stat_list=['cumulative_rew'], labels=['Reward'], figsize=(6, 4), titlesize=14)
skill_kwargs = dict(figsize=(5,5), reset_dict=dict(state=torch.tensor([0., -0.5])))

# %% [markdown]
# ## Map: UPSIDE, Sampling: Oracle, SR: Yes

# %%
exp, cmap = load_exp_data("square_upside/edl_sr_oracle_upside")
plot_stats_by_name(exp, **plot_kwargs)
ax = plot_all_skills(exp, cmap, title="EDL+SR+upside (oracle)", **skill_kwargs)
# Out:
# ...
# Trajectories:   0%|          | 0/20 [00:00<?, ?it/s]

# %% [markdown]
# ## Map: UPSIDE, Sampling: SMM SR: Yes

# %%
exp, cmap = load_exp_data("square_upside/edl_sr_smm_upside")
plot_stats_by_name(exp, **plot_kwargs)
ax = plot_all_skills(exp, cmap, title="EDL+SR+upisde (SMM exploration)", **skill_kwargs)
# Out:
# ...
# Trajectories:   0%|          | 0/20 [00:00<?, ?it/s]

# %% [markdown]
# ## Map: BOTTLENECK, Sampling: Oracle, SR: Yes

# %% [markdown]
# ### 1번시드

# %%
exp, cmap = load_exp_data("square_bottleneck/edl_sr_oracle_bottleneck")
plot_stats_by_name(exp, **plot_kwargs)
ax = plot_all_skills(exp, cmap, title="EDL+SR+bottleneck (oracle)", **skill_kwargs)
# Out:
# ...
# Trajectories:   0%|          | 0/20 [00:00<?, ?it/s]

# %% [markdown]
# ### 2번시드

# %%
exp, cmap = load_exp_data("square_bottleneck2/edl_sr_oracle_bottleneck")
plot_stats_by_name(exp, **plot_kwargs)
ax = plot_all_skills(exp, cmap, title="EDL+SR+bottleneck (oracle)", **skill_kwargs)
# Out:
# ...
# Trajectories:   0%|          | 0/20 [00:00<?, ?it/s]

# %% [markdown]
# ### 3번시드

# %%
exp, cmap = load_exp_data("square_bottleneck3/edl_sr_oracle_bottleneck")
plot_stats_by_name(exp, **plot_kwargs)
ax = plot_all_skills(exp, cmap, title="EDL+SR+bottleneck (oracle)", **skill_kwargs)
# Out:
# ...
# Trajectories:   0%|          | 0/20 [00:00<?, ?it/s]

# %% [markdown]
# ## Map: BOTTLENECK, Sampling: SMM, SR: Yes

# %%
exp, cmap = load_exp_data("square_bottleneck/edl_sr_smm_bottleneck")
plot_stats_by_name(exp, **plot_kwargs)
ax = plot_all_skills(exp, cmap, title="EDL+SR+bottleneck (SMM)", **skill_kwargs)
# Out:
# ...
# Trajectories:   0%|          | 0/20 [00:00<?, ?it/s]
